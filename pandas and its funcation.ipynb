# %%
import pandas as pd

# %%
#creating a series
s=pd.Series([1,2,3,4,5])

# %%
#print the series s
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# creating series with Index
s=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])

# %%
# Index with series
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
#print index of series S
print(s[0])
# Out:
# 1

# %%
#printing the index number of 'd'
print(s['d'])
# Out:
# 4

# %%
#creating the dataframe
d=pd.DataFrame([1,2,3,4])

# %%
#print the dataframe d
d
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
#creating a dataframe c
c=pd.DataFrame({'name':['tom','dick','harry'],'Age':[28,29,20]})

# %%
#printing a dataframe c
c
# Out:
#     name  Age
# 0    tom   28
# 1   dick   29
# 2  harry   20

# %%
#creating a new dataframe with Index
c=pd.DataFrame({'name':['tom','dick','harry'],'Age':[28,29,20]},index=["c1","c2","c3"])

# %%
# print the dataframe
c
# Out:
#      name  Age
# c1    tom   28
# c2   dick   29
# c3  harry   20

# %%
c.loc['c1','Age']
# Out:
# 28

# %%
c.iloc[2,1]
# Out:
# 20

# %%
name=pd.DataFrame({"name":["abhinav","narayan","kushal"]})
age=pd.DataFrame({'Ages':[20,21,22]})

# %%
l=pd.concat([name,age],axis=1)

# %%
l
# Out:
#       name  Ages
# 0  abhinav    20
# 1  narayan    21
# 2   kushal    22

# %%
l[l['Ages']<=25][['name']]
# Out:
#       name
# 0  abhinav
# 1  narayan
# 2   kushal

# %%
r=pd.DataFrame({'name':["abhi","nar","nil"],'Age':[20,21,22],'University':['Amity','BHU','IIT']})

# %%
r
# Out:
#    name  Age University
# 0  abhi   20      Amity
# 1   nar   21        BHU
# 2   nil   22        IIT

# %%
r.to_csv('student.csv',index=False)

# %%
l=pd.read_csv('student.csv')

# %%
l
# Out:
#    name  Age University
# 0  abhi   20      Amity
# 1   nar   21        BHU
# 2   nil   22        IIT

# %%
l['city']=['Noida','Banarus','Delhi']

# %%
l
# Out:
#    name  Age University     city
# 0  abhi   20      Amity    Noida
# 1   nar   21        BHU  Banarus
# 2   nil   22        IIT    Delhi

# %%
l.columns=['First_name','Current_Age','Collage_University','Location']

# %%
l
# Out:
#   First_name  Current_Age Collage_University Location
# 0       abhi           20              Amity    Noida
# 1        nar           21                BHU  Banarus
# 2        nil           22                IIT    Delhi

# %%
l.drop(columns=['Current_Age'],axis=1,inplace=True)

# %%
l
# Out:
#   First_name Collage_University Location
# 0       abhi              Amity    Noida
# 1        nar                BHU  Banarus
# 2        nil                IIT    Delhi

# %%
data=pd.DataFrame({'name':['A','A','A','A','B','B','B','B'],'Points':[10,10,12,12,15,17,20,20],'assits':[5,5,7,9,12,9,6,6]})

# %%
data
# Out:
#   name  Points  assits
# 0    A      10       5
# 1    A      10       5
# 2    A      12       7
# 3    A      12       9
# 4    B      15      12
# 5    B      17       9
# 6    B      20       6
# 7    B      20       6

# %%
d=data.duplicated()

# %%
data[d]
# Out:
#   name  Points  assits
# 1    A      10       5
# 7    B      20       6

# %% [markdown]
# team=data.duplicate(['name'])

# %%
team=data.duplicated(['name'])

# %%
data[team
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5     True
# 6     True
# 7     True
# dtype: bool

# %%
data.drop_duplicates()
# Out:
#   name  Points  assits
# 0    A      10       5
# 2    A      12       7
# 3    A      12       9
# 4    B      15      12
# 5    B      17       9
# 6    B      20       6
